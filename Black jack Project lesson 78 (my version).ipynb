# %%
import random

def deal_cards():
    
    cards = [ 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
    my_cards = []
    computer_cards = []
    play_game = input("Do you want to play a game of Blackjack? Type 'y' or 'n': ")
    
    # Determine if the player wants toplaynthe game
    
    if play_game == 'n':
        print('Sorry to see you go :( Bye!')
        return
    elif play_game != 'n' and play_game != 'y':
        print('Opps, invalid entry, try again!')
        deal_cards()
    else:
        for x in range(2):
            my_cards.append(random.choice(cards))
            computer_cards.append(random.choice(cards)
       
        
            
#user_score = sum(my_cards)
#print(f'Your cards are: {my_cards}, your current score: {score}')
#        
#         computer_card = 
#         computer_score = 
#         print(f"Computer's first card: {computer_reveal}")
        

    


def calculate_score(cards):  
    
    if sum(cards) == 21 and len(my_cards)==2:
        score = 0
        print('You win with Blackjack!')
        return 0
        
        
#         comp_final_score = 
#         print(f'Your final hand: {my_cards}, your final score: { my_final_score}')
#         print(f"Computer's final hand: {computer_reveal}, final score: {comp_final_score}")
#         print('You win with Blackjack!')
    
    if 11 in cards and sum(cards)>21:
        cards.remove(11)
        cards.append(1)
    
    return sum(cards)


    continue_game = True

def end_game():
        my_final_hand = my_cards
        my_final_score = score
        comp_final_hand = computer_cards
        comp_final_score = sum(computer_cards)
        print(f'Your final hand is: {my_final_hand }, your final score: {my_final_score}.')
        print(f"Computer's final hand: {comp_final_hand}, final score: {comp_final_score}.")
            
        #Determine the conditions for winning or losing the game

        if comp_final_score < my_final_score <=21:
            print('Congratulations! You won!')
        elif comp_final_score > 21 and my_final_score <= 21:
            print('Congratulations! You won!')
        elif comp_final_score == my_final_score:
            print('It is a tie!')
        elif my_final_score < comp_final_score <= 21:
            print('Oopps, you lost the game!')
        else:
            print('Oopps, you lost the game!')
                
        pick_cards()

    while continue_game:
            
        if score >= 21:
            end_game()
            return

        choice = input("Type 'y' to get another card or type 'n' to pass: ")

        if choice == 'y':
            my_cards.append(random.choice(card_value))
            score = sum(my_cards)

            print(f'Your cards are: {my_cards}, your current score: {score}')

            print(f"Computer's first card: {computer_reveal}")

        else:
            end_game() 
            pick_cards()  
pick_cards()
# Out:
#   Input In [4]
#     def calculate_score(cards):
#     ^
# SyntaxError: invalid syntax
